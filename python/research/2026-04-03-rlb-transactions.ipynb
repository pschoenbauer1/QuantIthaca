# %%
import pandas as pd
import re

# datapath = r"C:\Users\phili\OneDrive\Vermietung\.data"
datapath = r"C:\Users\phili\OneDrive\Konten\Raiffeisen\Transactions_csv"

# %%
filename = r"C:\Users\phili\OneDrive\Konten\Raiffeisen\Transactions_csv\RLB-CURRENT-0_2025_meinElba_umsaetze_AT353200000007623556.csv"

def custom_date_parser(date_string):
    return pd.to_datetime(date_string, format='%d.%m.%Y')

data_raw = pd.read_csv(filename, sep=";", header=None)
data_raw.columns = ["date", "description", "ref_date", "amount", "ccy", "timestamp"]

#data_raw["ref_cashflow"] = "AT353200000007623556"
# data_raw_1 = pd.read_csv(filename_1, sep=";", header=None)
# data_raw_1["ref_cashflow"] = "AT793200000107623556"
# data_raw = pd.concat([data_raw,data_raw_1],axis=0)
# data_raw["date"] = data_raw["date"].apply(custom_date_parser)
# data_raw["ref_date"] = data_raw["ref_date"].apply(custom_date_parser)
# data_raw["date"] = data_raw["date"].apply(custom_date_parser)
# data_raw = data_raw.sort_values("ref_date")

# %%
data_raw
# Out:
#           date                                        description    ref_date  \
# 0   02.01.2025  Zahlungsempfänger: Allianz Elementar Versicher...  02.01.2025
# 1   02.01.2025  Zahlungsempfänger: Allianz Elementar Versicher...  02.01.2025
# 2   03.01.2025  Auftraggeber: Johann Spiessberger Verwendungsz...  03.01.2025
# 3   28.01.2025  ONLINE BANKING VOM 27.01 UM 21:47 Empfänger: L...  27.01.2025
# 4   28.01.2025  ONLINE BANKING VOM 27.01 UM 21:50 Empfänger: R...  27.01.2025
# 5   31.01.2025                     Zahlungsreferenz: Kontoführung  01.02.2025
# 6   04.02.2025  Auftraggeber: Johann Spiessberger Verwendungsz...  04.02.2025
# 7   28.02.2025                     Zahlungsreferenz: Kontoführung  01.03.2025
# 8   04.03.2025  Auftraggeber: Johann Spiessberger Verwendungsz...  04.03.2025
# 9   11.03.2025  Zahlungsempfänger: 1&1 Mail & Media GmbH Verwe...  11.03.2025
# 10  31.03.2025                     Zahlungsreferenz: Kontoführung  01.04.2025
# ...
